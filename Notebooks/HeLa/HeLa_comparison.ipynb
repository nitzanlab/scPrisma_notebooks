# %%
#######imports and data read#######
import copy
import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans

from pre_processing import *
from algorithms import *
from spectrum_gen import *
from data_gen import *
from analysis import *
from datasets import *
from evaluation import *
#cr_filtering()
#cr_read_norm()1dasdas
import h5py
import scanpy as sc
from sklearn.metrics import adjusted_rand_score
gene_list_for_plot = ['CDC20','CDK1','RRM2','PCNA','A1BG']

# %%
adata_cyclum = sc.read("hela/cyclum_circular_componenet.h5ad")
adata_cyclum.X = np.array(adata_cyclum.X).astype('float64')
all_plots_hela(adata_cyclum,'Cyclum circular component')
plot_gene_list(adata_cyclum, gene_list_for_plot +['A1BG'], color1='black', color2='purple', title="Cyclum circular component")
auc_cyclum= np.zeros(100)
for i in range(100):
    auc_cyclum[i] = hela_gene_inference(adata_cyclum, number_of_genes=100)
    print(auc_cyclum[i])
print("Mean AUC-ROC: " + str(np.mean(auc_cyclum)))
# Out:
# WARNING: You’re trying to run this on 6999 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# Circular mean and variance, G1S(0.8854501923911213, 0.2767504647998502)
# Circular mean and variance, S(-1.5857422969475201, 0.03901425507416856)
# Circular mean and variance, G2(1.120689494774752, -0.8256009418391899)
# Circular mean and variance, G2M(1.1283079810206156, -0.9232009747770642)
# Circular mean and variance, MG1(0.8869092499244692, 0.27413106602390847)
# Mean circular variance= -0.23178122614366536
# /Users/jonathankarin/.conda/envs/spctral_jan/lib/python3.9/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
# ...

# %%
adata_cyclum = sc.read("hela/cyclum_reordered.h5ad")
adata_cyclum.X = np.array(adata_cyclum.X).astype('float64')
plot_gene_list(adata_cyclum, gene_list_for_plot +['A1BG'], color1='black', color2='pink', title="Cyclum reordered")
all_plots_hela(adata_cyclum,'Cyclum reordered')
auc_cyclum_reordered= np.zeros(100)
for i in range(100):
    auc_cyclum_reordered[i] = hela_gene_inference(adata_cyclum, number_of_genes=100)
    print(auc_cyclum_reordered[i])
print("Mean AUC-ROC: " + str(np.mean(auc_cyclum_reordered)))
# Out:
# WARNING: You’re trying to run this on 6999 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# Circular mean and variance, G1S(0.43144996450682704, 0.9405714132170039)
# Circular mean and variance, S(-1.2505980498791518, 0.8875802154929356)
# Circular mean and variance, G2(-1.9580753595152796, 0.8503985375803719)
# Circular mean and variance, G2M(-2.038762516324523, 0.8636196320073323)
# Circular mean and variance, MG1(-2.385000018593726, 0.9254576188736227)
# Mean circular variance= 0.8935254834342532
# /Users/jonathankarin/.conda/envs/spctral_jan/lib/python3.9/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
# ...

# %%
auc_ordered = np.load("auc_ordered.npy")
auc_en = np.load("auc_en.npy")
auc_filtered = np.load("auc_filtered.npy")
auc_unordered = np.load("auc_unordered.npy")

# %%
data = pd.DataFrame({
    "Unordered": auc_unordered,
    'scPrisma- ordered': auc_ordered,
    "scPrisma- enhanced": auc_en,
    "scPrisma- filtered": auc_filtered,
    "Cyclum ordered": auc_cyclum_reordered,
    "Cyclum enhanced": auc_cyclum
})
sns.set_style("whitegrid")

sns.set_style("white", {"axes.facecolor": ".9"})
sns.set_style("whitegrid")

sns.set(font_scale=1)
ax = sns.violinplot(data=data)
ax.set(ylim=(0, 1))

plt.ylabel("AUC-ROC")
plt.title("AUC-ROC of cell cycle inference" ,fontsize='24')
plt.show()
sns.set_style("whitegrid")

b = sns.violinplot(data=data , vmin=0)
#b.axes.set_style("darkgrid", {"axes.facecolor": ".9"})
sns.set(rc={'figure.figsize':(23.4,16.54)})
b.axes.set_title("AUC-ROC of cell cycle genes inference",fontsize=40)
b.set_ylabel("AUC-ROC",fontsize=35)
b.tick_params(rotation=10,labelsize=35)
#b.axes.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")


sns.set(rc={'figure.figsize':(23.4,16.54)})
#plt.title("MSE between simulated cyclic signal and output of enhancement methods" ,fontsize='24')

sns.set_style("whitegrid")
ax.set(ylim=(0, 1))

plt.show()
#plt.style.use('default')

# %%
data = pd.DataFrame({
    "Unordered": auc_unordered,
    'scPrisma- ordered': auc_ordered,
    "scPrisma- enhanced": auc_en,
    "Cyclum ordered": auc_cyclum_reordered,
    "Cyclum enhanced": auc_cyclum
})
sns.set_style("whitegrid")

sns.set_style("white", {"axes.facecolor": ".9"})
sns.set_style("whitegrid")

sns.set(font_scale=1)
ax = sns.violinplot(data=data)
ax.set(ylim=(0, 1))

plt.ylabel("AUC-ROC")
plt.title("AUC-ROC of cell cycle inference" ,fontsize='24')
plt.show()
sns.set_style("whitegrid")

b = sns.violinplot(data=data , vmin=0)
#b.axes.set_style("darkgrid", {"axes.facecolor": ".9"})
sns.set(rc={'figure.figsize':(23.4,16.54)})
b.axes.set_title("AUC-ROC of cell cycle genes inference",fontsize=40)
b.set_ylabel("AUC-ROC",fontsize=35)
b.tick_params(rotation=10,labelsize=35)
#b.axes.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")


sns.set(rc={'figure.figsize':(23.4,16.54)})
#plt.title("MSE between simulated cyclic signal and output of enhancement methods" ,fontsize='24')

sns.set_style("whitegrid")
ax.set(ylim=(0, 1))

plt.show()
#plt.style.use('default')

# %%
a=1/0

plt.plot(adata_cyclum[:,'CDK1'].X)

adata_cyclum = sc.read("hela/cyclum_reordered.h5ad")

all_plots_hela(adata_cyclum,'Cyclum reordered')
plot_gene_list(adata_cyclum, gene_list_for_plot +['A1BG'], color1='black', color2='pink', title="Cyclum reordered")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 a=1/0
#       3 plt.plot(adata_cyclum[:,'CDK1'].X)
#       5 adata_cyclum = sc.read("hela/cyclum_reordered.h5ad")
#
# ZeroDivisionError: division by zero

# %%
def cyclum_for_hela(adata):
    model = cyclum.tuning.CyclumAutoTune(adata.X, max_linear_dims=10,
                                         epochs=500, rate=2e-4, verbose=100,
                                         encoder_width=[20, 30]) #500, 10
    model.train(adata.X, epochs=1000, verbose=100, rate=2e-4) #1000
    pseudotime = model.predict_pseudotime(adata.X)
    circular_comp = model.get_circular_component(pseudotime)
    flat_embedding = (pseudotime % (2 * np.pi)) / 2
    flat_embedding = flat_embedding[:,0]
    sort = np.argsort(flat_embedding)
    #print(sort)
    bdata = adata.copy()
    bdata = bdata[sort,:]
    bdata.write(filename="hela/cyclum_reordered.h5ad")
    adata.X = circular_comp
    adata = adata[sort,:]
    adata.write(filename="hela/cyclum_circular_componenet.h5ad")
    pass


adata = sc.read_csv('hela/GSM4224315_out_gene_exon_tagged.dge_exonssf002_WT.txt', delimiter='\t').T
adata = shuffle_adata(adata)
sc.pp.filter_cells(adata, min_genes=0)
i = 1
while adata.obs['n_genes'].mean() < 4500:  # remove cells until we reach mean counts of 4,500 as suggested by https://www.embopress.org/doi/full/10.15252/msb.20209946
    sc.pp.filter_cells(adata, min_genes=i)
    i += 5
sc.pp.normalize_per_cell(adata, counts_per_cell_after=1e4)
sc.pp.log1p(adata)
sc.pp.filter_genes_dispersion(adata, n_top_genes=7000)
cyclum_for_hela(adata)

# %%
data = pd.DataFrame({
    "Unordered": auc_unordered,
    'Ordered': auc_ordered,
    "Enhanced": auc_en,
    "Filtered": auc_filtered,
})
sns.set_style("whitegrid")

sns.set_style("white", {"axes.facecolor": ".9"})
sns.set_style("whitegrid")

sns.set(font_scale=2)
ax = sns.violinplot(data=data)
plt.ylabel("AUC-ROC")
plt.title("AUC-ROC of cell cycle inference" ,fontsize='24')
plt.show()
sns.set_style("whitegrid")

b = sns.violinplot(data=data)
#b.axes.set_style("darkgrid", {"axes.facecolor": ".9"})
sns.set(rc={'figure.figsize':(23.4,16.54)})
b.axes.set_title("AUC-ROC of cell cycle genes inference",fontsize=40)
b.set_ylabel("AUC-ROC",fontsize=35)
b.tick_params(rotation=10,labelsize=35)
#b.axes.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")


sns.set(rc={'figure.figsize':(23.4,16.54)})
#plt.title("MSE between simulated cyclic signal and output of enhancement methods" ,fontsize='24')

sns.set_style("whitegrid")

plt.show()
plt.style.use('default')

# %%
plt.style.use('default')
