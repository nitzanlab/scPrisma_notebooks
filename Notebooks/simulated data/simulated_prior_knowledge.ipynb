# %%
import copy

import matplotlib.pyplot as plt
import numpy as np
import scanpy as sc
import pandas as pd
from algorithms import *
from data_gen import *
from spectrum_gen import *
from visualizations import *
from analysis import *
import random

# %%
noise_list =[]

corr_list = []
snr_list = []
corr_list_in = []

T = simulate_spatial_cyclic(ngenes=500,ncells=99,w=0.3)
t_norm = np.linalg.norm(T)
indicator = np.zeros((99,99))
for i in range(33):
    for j in range(33):
        indicator[i,j]=1
        indicator[i+33,j+33]=1
        indicator[i+66,j+66]=1
    
for i in range(1000):
        print("Iteration number: " + str(i))
        noise = np.random.normal(0,0.2 + i*0.01,(T.shape))
        K = T + noise
        K = np.clip(K,0,np.inf)
        E_sga  , E_rec_sga = sga_m_reorder_rows_matrix(K,iterNum=100,batch_size=90)
        res = spearm(E_rec_sga,np.array(range(K.shape[0])))
        corr_list.append(res)
        noise_list.append(0.2 + i*0.01)
        print(res)
        noise_norm = np.linalg.norm(noise)
        snr = t_norm/noise_norm
        snr_list.append(snr)
        E_sga  , E_rec_sga = reorder_indicator(K,indicator,iterNum=100,batch_size=90)
        res = spearm(E_rec_sga,np.array(range(K.shape[0])))
        corr_list_in.append(res)
# Out:
# Iteration number: 0
# Iteration number:
# 0
#  function value=
# 3.230865904158546e-26
# Iteration number:
# 25
#  function value=
# 612.5161934000762
# Iteration number:
# 50
#  function value=
# 627.4587223299641
# Iteration number:
# 75
#  function value=
# 631.7531068871318
# 0.9999628942486084
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 110.87618023143486
# Iteration number: 50 function value= 112.7052036960608
# Iteration number: 75 function value= 113.4130665461004
# Iteration number: 1
# Iteration number:
# 0
#  function value=
# 3.157324812449317e-26
# Iteration number:
# 25
#  function value=
# 588.9682691494777
# Iteration number:
# 50
#  function value=
# 615.4355739194821
# Iteration number:
# 75
#  function value=
# 619.1899475078028
# 0.9999999999999999
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 112.98013725633754
# Iteration number: 50 function value= 111.13645754670355
# Iteration number: 75 function value= 110.58580024877533
# Iteration number: 2
# Iteration number:
# 0
#  function value=
# 3.2429464082823985e-26
# Iteration number:
# 25
#  function value=
# 575.7406089901667
# Iteration number:
# 50
#  function value=
# 602.7501514439307
# Iteration number:
# 75
#  function value=
# 607.7368521514267
# 0.9999999999999999
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 105.53970515861107
# Iteration number: 50 function value= 108.93335741017415
# Iteration number: 75 function value= 111.13520571348607
# Iteration number: 3
# Iteration number:
# 0
#  function value=
# 3.296004538429596e-26
# Iteration number:
# 25
#  function value=
# 537.125778331733
# Iteration number:
# 50
#  function value=
# 580.2998356967444
# Iteration number:
# 75
#  function value=
# 587.6910208872098
# 0.9871861471861472
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 105.98315744152072
# Iteration number: 50 function value= 106.42456598578545
# Iteration number: 75 function value= 105.37751370594724
# Iteration number: 4
# Iteration number:
# 0
#  function value=
# 3.2855831935628516e-26
# Iteration number:
# 25
#  function value=
# 561.161302572091
# Iteration number:
# 50
#  function value=
# 581.0061884083557
# Iteration number:
# 75
#  function value=
# 585.1887309152194
# 0.998491032776747
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 103.71389060360346
# Iteration number: 50 function value= 104.86769106217852
# Iteration number: 75 function value= 104.24162212644654
# Iteration number: 5
# Iteration number:
# 0
#  function value=
# 3.2881961544906386e-26
# Iteration number:
# 25
#  function value=
# 553.5927047558541
# Iteration number:
# 50
#  function value=
# 565.1029717624724
# Iteration number:
# 75
#  function value=
# 569.6097006243531
# 0.9999752628324056
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 98.8421132748827
# Iteration number: 50 function value= 101.74814380830105
# Iteration number: 75 function value= 101.3456240241812
# Iteration number: 6
# Iteration number:
# 0
#  function value=
# 3.2567139867127773e-26
# Iteration number:
# 25
#  function value=
# 542.4115712470654
# Iteration number:
# 50
#  function value=
# 556.4467361398688
# Iteration number:
# 75
#  function value=
# 560.061008484895
# 0.9934322820037105
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 100.35818004312718
# Iteration number: 50 function value= 99.57383417058729
# Iteration number: 75 function value= 102.073918711278
# Iteration number: 7
# Iteration number:
# 0
#  function value=
# 3.317819109355296e-26
# Iteration number:
# 25
#  function value=
# 509.8948426555651
# Iteration number:
# 50
#  function value=
# 546.5299022106994
# Iteration number:
# 75
#  function value=
# 551.5375423615171
# 0.9999628942486084
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 98.48273446476544
# Iteration number: 50 function value= 96.88875017258809
# Iteration number: 75 function value= 99.41753924703289
# Iteration number: 8
# Iteration number:
# 0
#  function value=
# 3.2882202129387396e-26
# Iteration number:
# 25
#  function value=
# 518.2672256955321
# Iteration number:
# 50
#  function value=
# 535.514092606691
# Iteration number:
# 75
#  function value=
# 539.3381097100956
# 0.9999505256648114
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 97.72109370946
# Iteration number: 50 function value= 95.34430662329746
# Iteration number: 75 function value= 97.11094635660149
# Iteration number: 9
# Iteration number:
# 0
#  function value=
# 3.350486801096588e-26
# Iteration number:
# 25
#  function value=
# 497.8707181952268
# Iteration number:
# 50
#  function value=
# 522.7084717376733
# Iteration number:
# 75
#  function value=
# 527.8072661955234
# 0.9999381570810142
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 94.72748121786648
# Iteration number: 50 function value= 96.09390492195321
# Iteration number: 75 function value= 94.44699801341483
# Iteration number: 10
# Iteration number:
# 0
#  function value=
# 3.3489077247877474e-26
# Iteration number:
# 25
#  function value=
# 484.056878620177
# Iteration number:
# 50
#  function value=
# 512.4331851248514
# Iteration number:
# 75
#  function value=
# 516.6991865444719
# 0.9997897340754484
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 91.33677293413035
# Iteration number: 50 function value= 93.56503934159883
# Iteration number: 75 function value= 91.23923144325578
# Iteration number: 11
# Iteration number:
# 0
#  function value=
# 3.3777981439040627e-26
# Iteration number:
# 25
#  function value=
# 486.8538734026207
# Iteration number:
# 50
#  function value=
# 503.5497870362202
# Iteration number:
# 75
#  function value=
# 506.68868120324225
# 0.9999134199134199
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 90.58185563346922
# Iteration number: 50 function value= 89.93434589586103
# Iteration number: 75 function value= 92.33497785052668
# Iteration number: 12
# Iteration number:
# 0
#  function value=
# 3.4181813923503816e-26
# Iteration number:
# 25
#  function value=
# 475.5953621512555
# Iteration number:
# 50
#  function value=
# 492.6969662142973
# Iteration number:
# 75
#  function value=
# 495.53042343057643
# 0.9999134199134199
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 88.85026719287653
# Iteration number: 50 function value= 87.78290185505983
# Iteration number: 75 function value= 87.44566387525674
# Iteration number: 13
# Iteration number:
# 0
#  function value=
# 3.38922806103576e-26
# Iteration number:
# 25
#  function value=
# 436.32227409292796
# Iteration number:
# 50
#  function value=
# 475.8860910675192
# Iteration number:
# 75
#  function value=
# 480.9998633195688
# 0.9999134199134199
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 83.409876461987
# Iteration number: 50 function value= 87.16206632508406
# Iteration number: 75 function value= 85.99370436359159
# Iteration number: 14
# Iteration number:
# 0
#  function value=
# 3.347494579888052e-26
# Iteration number:
# 25
#  function value=
# 442.07457313050094
# Iteration number:
# 50
#  function value=
# 470.27485694943425
# Iteration number:
# 75
#  function value=
# 471.2629133014873
# 0.9990723562152134
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 80.95086058739945
# Iteration number: 50 function value= 86.02464988547706
# Iteration number: 75 function value= 84.29652350998288
# Iteration number: 15
# Iteration number:
# 0
#  function value=
# 3.2952170570536434e-26
# Iteration number:
# 25
#  function value=
# 422.76609246305765
# Iteration number:
# 50
#  function value=
# 460.87342687385916
# Iteration number:
# 75
#  function value=
# 465.0915180209753
# 0.9993197278911563
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 81.38545737912976
# Iteration number: 50 function value= 84.98852429244448
# Iteration number: 75 function value= 84.93045459073115
# Iteration number: 16
# Iteration number:
# 0
#  function value=
# 3.416592148596615e-26
# Iteration number:
# 25
#  function value=
# 406.9269361560035
# Iteration number:
# 50
#  function value=
# 446.4650946436983
# Iteration number:
# 75
#  function value=
# 452.51269349957187
# 0.9999134199134199
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 79.66570439193544
# Iteration number: 50 function value= 78.82919706226375
# Iteration number: 75 function value= 83.13982784942587
# Iteration number: 17
# Iteration number:
# 0
#  function value=
# 3.260797755829127e-26
# Iteration number:
# 25
#  function value=
# 429.02741068982067
# Iteration number:
# 50
#  function value=
# 442.93100373640516
# Iteration number:
# 75
#  function value=
# 447.0777649515653
# 0.9990723562152134
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 79.94276514752751
# Iteration number: 50 function value= 78.5626956633392
# Iteration number: 75 function value= 81.14214748989909
# Iteration number: 18
# Iteration number:
# 0
#  function value=
# 3.2566392135355896e-26
# Iteration number:
# 25
#  function value=
# 420.5946810539661
# Iteration number:
# 50
#  function value=
# 436.2803047495182
# Iteration number:
# 75
#  function value=
# 436.92223272880915
# 0.9998021026592454
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 78.99880834382225
# Iteration number: 50 function value= 75.77443972721517
# Iteration number: 75 function value= 80.18532498380131
# Iteration number: 19
# Iteration number:
# 0
#  function value=
# 3.304328196402967e-26
# Iteration number:
# 25
#  function value=
# 404.09136533727434
# Iteration number:
# 50
#  function value=
# 423.2665135046202
# Iteration number:
# 75
#  function value=
# 427.0191190945882
# 0.9999505256648114
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 75.33845672836222
# Iteration number: 50 function value= 74.77266815283298
# Iteration number: 75 function value= 77.03993622483858
# Iteration number: 20
# Iteration number:
# 0
#  function value=
# 3.2809040571767154e-26
# Iteration number:
# 25
#  function value=
# 392.9237417690183
# Iteration number:
# 50
#  function value=
# 414.2108857790495
# Iteration number:
# 75
#  function value=
# 415.3514446694093
# 0.999851576994434
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 74.1041838824745
# Iteration number: 50 function value= 73.00227883516393
# Iteration number: 75 function value= 77.37056622226251
# Iteration number: 21
# Iteration number:
# 0
#  function value=
# 3.3503592290994756e-26
# Iteration number:
# 25
#  function value=
# 380.1548734763856
# Iteration number:
# 50
#  function value=
# 406.23912993660224
# Iteration number:
# 75
#  function value=
# 408.3986993060523
# 0.9998886827458254
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 72.79846191718525
# Iteration number: 50 function value= 72.3122392505907
# Iteration number: 75 function value= 71.40717376257626
# Iteration number: 22
# Iteration number:
# 0
#  function value=
# 3.2664324231824865e-26
# Iteration number:
# 25
#  function value=
# 379.0669739335793
# Iteration number:
# 50
#  function value=
# 395.9371340413268
# Iteration number:
# 75
#  function value=
# 397.7865360297841
# 0.9998021026592454
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 68.77701064122587
# Iteration number: 50 function value= 69.13498896612217
# Iteration number: 75 function value= 70.28181765673126
# Iteration number: 23
# Iteration number:
# 0
#  function value=
# 3.332340315752803e-26
# Iteration number:
# 25
#  function value=
# 367.26658623791974
# Iteration number:
# 50
#  function value=
# 385.2215280234914
# Iteration number:
# 75
#  function value=
# 388.5390210399215
# 0.9999010513296226
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 68.41610131196595
# Iteration number: 50 function value= 69.60469277220199
# Iteration number: 75 function value= 73.44089946455509
# Iteration number: 24
# Iteration number:
# 0
#  function value=
# 3.267398821023661e-26
# Iteration number:
# 25
#  function value=
# 226.69184216326454
# Iteration number:
# 50
#  function value=
# 379.7424026224597
# Iteration number:
# 75
#  function value=
# 381.0350589984745
# 0.997773654916512
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 69.66851056498113
# Iteration number: 50 function value= 67.98068729192593
# Iteration number: 75 function value= 69.93574402342861
# Iteration number: 25
# Iteration number:
# 0
#  function value=
# 3.387472688443986e-26
# Iteration number:
# 25
#  function value=
# 355.01921868560987
# Iteration number:
# 50
#  function value=
# 374.9637475572881
# Iteration number:
# 75
#  function value=
# 377.9477277311886
# 0.9998639455782312
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 65.4255592766537
# Iteration number: 50 function value= 66.02612821128338
# Iteration number: 75 function value= 67.74635545086666
# Iteration number: 26
# Iteration number:
# 0
#  function value=
# 3.3185450385883335e-26
# Iteration number:
# 25
#  function value=
# 330.6090407049012
# Iteration number:
# 50
#  function value=
# 366.3497782076634
# Iteration number:
# 75
#  function value=
# 369.8816174070098
# 0.9410142238713666
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 65.62914968316743
# Iteration number: 50 function value= 70.19927532400271
# Iteration number: 75 function value= 67.26779814735119
# Iteration number: 27
# Iteration number:
# 0
#  function value=
# 3.328122756893224e-26
# Iteration number:
# 25
#  function value=
# 333.2982909479738
# Iteration number:
# 50
#  function value=
# 351.5551931595629
# Iteration number:
# 75
#  function value=
# 354.83390268595724
# 0.9997031539888682
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 60.342777605324315
# Iteration number: 50 function value= 64.43333909030669
# Iteration number: 75 function value= 64.16744816703812
# Iteration number: 28
# Iteration number:
# 0
#  function value=
# 3.4143871788229623e-26
# Iteration number:
# 25
#  function value=
# 323.19767760797583
# Iteration number:
# 50
#  function value=
# 344.9111602773742
# Iteration number:
# 75
#  function value=
# 348.51368428123607
# 0.9996413110698824
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 62.53304592350195
# Iteration number: 50 function value= 62.3161591063002
# Iteration number: 75 function value= 59.23046980745703
# Iteration number: 29
# Iteration number:
# 0
#  function value=
# 3.309993198089311e-26
# Iteration number:
# 25
#  function value=
# 250.6603929195532
# Iteration number:
# 50
#  function value=
# 336.43852230045843
# Iteration number:
# 75
#  function value=
# 340.30881985339465
# 0.9997897340754484
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 58.2137821607696
# Iteration number: 50 function value= 63.04534998170618
# Iteration number: 75 function value= 61.18017617977445
# Iteration number: 30
# Iteration number:
# 0
#  function value=
# 3.324461246479178e-26
# Iteration number:
# 25
#  function value=
# 160.85171716251003
# Iteration number:
# 50
#  function value=
# 329.29133601274754
# Iteration number:
# 75
#  function value=
# 332.6573534788887
# 0.9420037105751391
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 58.90206025010586
# Iteration number: 50 function value= 58.10822189731399
# Iteration number: 75 function value= 57.77443087709024
# Iteration number: 31
# Iteration number:
# 0
#  function value=
# 3.2421900642098113e-26
# Iteration number:
# 25
#  function value=
# 303.0786663018606
# Iteration number:
# 50
#  function value=
# 328.2541101132741
# Iteration number:
# 75
#  function value=
# 331.21446425973113
# 0.9996289424860854
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 55.248474523013
# Iteration number: 50 function value= 57.92121751507642
# Iteration number: 75 function value= 57.50063293812802
# Iteration number: 32
# Iteration number:
# 0
#  function value=
# 3.265344041033935e-26
# Iteration number:
# 25
#  function value=
# 193.1010017636599
# Iteration number:
# 50
#  function value=
# 313.680661152355
# Iteration number:
# 75
#  function value=
# 317.30392094893546
# 0.9996907854050711
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 57.63922347438475
# Iteration number: 50 function value= 58.508904145213094
# Iteration number: 75 function value= 54.55536364219384
# Iteration number: 33
# Iteration number:
# 0
#  function value=
# 3.3194642697487863e-26
# Iteration number:
# 25
#  function value=
# 298.17455203125996
# Iteration number:
# 50
#  function value=
# 314.7684825201715
# Iteration number:
# 75
#  function value=
# 317.5268659757784
# 0.9422016079158936
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 56.05097965193143
# Iteration number: 50 function value= 59.644393474158676
# Iteration number: 75 function value= 55.50742327814283
# Iteration number: 34
# Iteration number:
# 0
#  function value=
# 3.323993297994368e-26
# Iteration number:
# 25
#  function value=
# 276.1446771845016
# Iteration number:
# 50
#  function value=
# 301.0156430762256
# Iteration number:
# 75
#  function value=
# 303.7388330615126
# 0.9995547309833024
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 53.01320760383866
# Iteration number: 50 function value= 54.5032575017902
# Iteration number: 75 function value= 54.613279286228234
# Iteration number: 35
# Iteration number:
# 0
#  function value=
# 3.330673295487381e-26
# Iteration number:
# 25
#  function value=
# 154.06570037258982
# Iteration number:
# 50
#  function value=
# 300.8811753214726
# Iteration number:
# 75
#  function value=
# 303.8772878592073
# 0.9405442176870746
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 52.03675753110002
# Iteration number: 50 function value= 53.35392697509758
# Iteration number: 75 function value= 55.98364346183591
# Iteration number: 36
# Iteration number:
# 0
#  function value=
# 3.2422205777064447e-26
# Iteration number:
# 25
#  function value=
# 224.66862539943526
# Iteration number:
# 50
#  function value=
# 294.5130630748333
# Iteration number:
# 75
#  function value=
# 297.28343117371105
# 0.9997278911564624
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 53.597341928068715
# Iteration number: 50 function value= 52.42401849971351
# Iteration number: 75 function value= 53.84565462744932
# Iteration number: 37
# Iteration number:
# 0
#  function value=
# 3.27562817748147e-26
# Iteration number:
# 25
#  function value=
# 261.92283582545326
# Iteration number:
# 50
#  function value=
# 285.32256534957673
# Iteration number:
# 75
#  function value=
# 288.78271221817243
# 0.9894495980210265
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 49.82175900515519
# Iteration number: 50 function value= 52.18908563686981
# Iteration number: 75 function value= 48.850239020977156
# Iteration number: 38
# Iteration number:
# 0
#  function value=
# 3.3090728273831405e-26
# Iteration number:
# 25
#  function value=
# 221.38078042329107
# Iteration number:
# 50
#  function value=
# 279.5298465687671
# Iteration number:
# 75
#  function value=
# 282.6104628878812
# 0.9994063079777364
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 49.88474677225622
# Iteration number: 50 function value= 49.29150525785197
# Iteration number: 75 function value= 50.23497384003696
# Iteration number: 39
# Iteration number:
# 0
#  function value=
# 3.237548231223342e-26
# Iteration number:
# 25
#  function value=
# 147.5061681992023
# Iteration number:
# 50
#  function value=
# 275.97348044865595
# Iteration number:
# 75
#  function value=
# 279.484715271004
# 0.942077922077922
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 48.603441396320484
# Iteration number: 50 function value= 46.63054930689324
# Iteration number: 75 function value= 48.56516869273378
# Iteration number: 40
# Iteration number:
# 0
#  function value=
# 3.2275044585695927e-26
# Iteration number:
# 25
#  function value=
# 131.85594259561958
# Iteration number:
# 50
#  function value=
# 260.80580455283985
# Iteration number:
# 75
#  function value=
# 267.7967586895835
# 0.9360915275200988
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 50.90872291323957
# Iteration number: 50 function value= 48.045909232706705
# Iteration number: 75 function value= 50.563593272261556
# Iteration number: 41
# Iteration number:
# 0
#  function value=
# 3.36261629444726e-26
# Iteration number:
# 25
#  function value=
# 143.6617828453249
# Iteration number:
# 50
#  function value=
# 263.5857912263685
# Iteration number:
# 75
#  function value=
# 266.64336137834437
# 0.9970191713048856
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 47.631311154787795
# Iteration number: 50 function value= 46.62456257442177
# Iteration number: 75 function value= 46.52730925037369
# Iteration number: 42
# Iteration number:
# 0
#  function value=
# 3.2511836200595134e-26
# Iteration number:
# 25
#  function value=
# 128.01765285670618
# Iteration number:
# 50
#  function value=
# 257.5409190753901
# Iteration number:
# 75
#  function value=
# 262.30267543123136
# 0.9875819418676561
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 46.885278693125876
# Iteration number: 50 function value= 46.518039743304584
# Iteration number: 75 function value= 46.916985819734414
# Iteration number: 43
# Iteration number:
# 0
#  function value=
# 3.299663496889793e-26
# Iteration number:
# 25
#  function value=
# 184.25016161162142
# Iteration number:
# 50
#  function value=
# 255.41976282592134
# Iteration number:
# 75
#  function value=
# 259.04204622067977
# 0.9883858998144712
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 45.030920224608394
# Iteration number: 50 function value= 45.16702710371264
# Iteration number: 75 function value= 48.566808552653185
# Iteration number: 44
# Iteration number:
# 0
#  function value=
# 3.252794214277583e-26
# Iteration number:
# 25
#  function value=
# 119.80601492766384
# Iteration number:
# 50
#  function value=
# 250.95184172503488
# Iteration number:
# 75
#  function value=
# 252.67103741854322
# 0.9553370439084724
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 44.34677922146613
# Iteration number: 50 function value= 43.27601512803747
# Iteration number: 75 function value= 45.412043340050374
# Iteration number: 45
# Iteration number:
# 0
#  function value=
# 3.2440270312975274e-26
# Iteration number:
# 25
#  function value=
# 112.6145809490067
# Iteration number:
# 50
#  function value=
# 241.01905256522468
# Iteration number:
# 75
#  function value=
# 244.19079376738108
# 0.9166728509585652
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 43.0480242799992
# Iteration number: 50 function value= 43.587005875227376
# Iteration number: 75 function value= 43.19919848642782
# Iteration number: 46
# Iteration number:
# 0
#  function value=
# 3.282245146050581e-26
# Iteration number:
# 25
#  function value=
# 154.48356998068954
# Iteration number:
# 50
#  function value=
# 242.14516529228365
# Iteration number:
# 75
#  function value=
# 244.3738950696029
# 0.9424984539270254
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 42.7910325956151
# Iteration number: 50 function value= 43.221803261153774
# Iteration number: 75 function value= 43.46638063355505
# Iteration number: 47
# Iteration number:
# 0
#  function value=
# 3.234352432359227e-26
# Iteration number:
# 25
#  function value=
# 110.55612822623232
# Iteration number:
# 50
#  function value=
# 232.90892363850736
# Iteration number:
# 75
#  function value=
# 234.86974294690646
# 0.9402102659245517
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 39.81964886928962
# Iteration number: 50 function value= 41.284191110329445
# Iteration number: 75 function value= 42.242519951714996
# Iteration number: 48
# Iteration number:
# 0
#  function value=
# 3.1921094703186823e-26
# Iteration number:
# 25
#  function value=
# 111.80594395120946
# Iteration number:
# 50
#  function value=
# 237.12178517667326
# Iteration number:
# 75
#  function value=
# 238.62254594806635
# 0.937847866419295
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 40.42004016389416
# Iteration number: 50 function value= 41.20858460191965
# Iteration number: 75 function value= 41.671968635609716
# Iteration number: 49
# Iteration number:
# 0
#  function value=
# 3.2487120335139266e-26
# Iteration number:
# 25
#  function value=
# 103.21567132084607
# Iteration number:
# 50
#  function value=
# 225.56081977389894
# Iteration number:
# 75
#  function value=
# 230.13492690603536
# 0.9990970933828076
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 40.2223749502939
# Iteration number: 50 function value= 40.91539337997774
# Iteration number: 75 function value= 40.11941338709431
# Iteration number: 50
# Iteration number:
# 0
#  function value=
# 3.269764285936177e-26
# Iteration number:
# 25
#  function value=
# 120.52825388237758
# Iteration number:
# 50
#  function value=
# 227.34246729322794
# Iteration number:
# 75
#  function value=
# 229.19735540288173
# 0.9993939393939392
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 43.39816101824431
# Iteration number: 50 function value= 40.77771287331888
# Iteration number: 75 function value= 39.678644988923594
# Iteration number: 51
# Iteration number:
# 0
#  function value=
# 3.169659690572778e-26
# Iteration number:
# 25
#  function value=
# 100.04431039519213
# Iteration number:
# 50
#  function value=
# 215.2338911636576
# Iteration number:
# 75
#  function value=
# 220.79054650063253
# 0.9989734075448361
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 34.815886988044944
# Iteration number: 50 function value= 40.94749211741956
# Iteration number: 75 function value= 39.80662005487554
# Iteration number: 52
# Iteration number:
# 0
#  function value=
# 3.2175826987270395e-26
# Iteration number:
# 25
#  function value=
# 93.22414443999799
# Iteration number:
# 50
#  function value=
# 213.17333975990852
# Iteration number:
# 75
#  function value=
# 215.35638312906767
# 0.9978973407544836
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 38.98046893098852
# Iteration number: 50 function value= 37.82538981178222
# Iteration number: 75 function value= 40.47794217948881
# Iteration number: 53
# Iteration number:
# 0
#  function value=
# 3.2373988077498465e-26
# Iteration number:
# 25
#  function value=
# 99.13436335042199
# Iteration number:
# 50
#  function value=
# 214.7512433757406
# Iteration number:
# 75
#  function value=
# 217.59537451736594
# 0.999208410636982
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 35.77679432732437
# Iteration number: 50 function value= 39.22633794256449
# Iteration number: 75 function value= 41.28699970425498
# Iteration number: 54
# Iteration number:
# 0
#  function value=
# 3.0571479263654477e-26
# Iteration number:
# 25
#  function value=
# 94.76678011930414
# Iteration number:
# 50
#  function value=
# 204.63195842417667
# Iteration number:
# 75
#  function value=
# 210.3444494342846
# 0.9402721088435374
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 38.06541326641168
# Iteration number: 50 function value= 40.22917018587926
# Iteration number: 75 function value= 36.496854290384405
# Iteration number: 55
# Iteration number:
# 0
#  function value=
# 3.163320029741286e-26
# Iteration number:
# 25
#  function value=
# 90.6725121171259
# Iteration number:
# 50
#  function value=
# 207.16497614798874
# Iteration number:
# 75
#  function value=
# 209.4903597093029
# 0.9991465677179963
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 37.96485624392699
# Iteration number: 50 function value= 34.009622478859626
# Iteration number: 75 function value= 36.95392545232603
# Iteration number: 56
# Iteration number:
# 0
#  function value=
# 3.036181246313189e-26
# Iteration number:
# 25
#  function value=
# 89.54262856928044
# Iteration number:
# 50
#  function value=
# 204.00619222034172
# Iteration number:
# 75
#  function value=
# 206.14049936993325
# 0.9989363017934446
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 36.432602629693974
# Iteration number: 50 function value= 39.098706032642625
# Iteration number: 75 function value= 39.34604180616184
# Iteration number: 57
# Iteration number:
# 0
#  function value=
# 3.2323902035474865e-26
# Iteration number:
# 25
#  function value=
# 88.88773767693114
# Iteration number:
# 50
#  function value=
# 199.67551525733944
# Iteration number:
# 75
#  function value=
# 203.37800336380553
# 0.9415708101422385
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 37.86738623393114
# Iteration number: 50 function value= 38.39609250976967
# Iteration number: 75 function value= 36.63120320393249
# Iteration number: 58
# Iteration number:
# 0
#  function value=
# 3.179929331914884e-26
# Iteration number:
# 25
#  function value=
# 83.88799823164044
# Iteration number:
# 50
#  function value=
# 193.78486997174537
# Iteration number:
# 75
#  function value=
# 196.62008693357507
# 0.9400371057513915
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 32.48486159355615
# Iteration number: 50 function value= 35.88215846980359
# Iteration number: 75 function value= 37.145097573845234
# Iteration number: 59
# Iteration number:
# 0
#  function value=
# 3.231704030619809e-26
# Iteration number:
# 25
#  function value=
# 80.33810871587107
# Iteration number:
# 50
#  function value=
# 187.70283155375634
# Iteration number:
# 75
#  function value=
# 190.3772794256837
# 0.941756338899196
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 32.26601569197872
# Iteration number: 50 function value= 34.78193917192688
# Iteration number: 75 function value= 34.329664883320106
# Iteration number: 60
# Iteration number:
# 0
#  function value=
# 3.195099829897363e-26
# Iteration number:
# 25
#  function value=
# 77.17311615565866
# Iteration number:
# 50
#  function value=
# 182.98940362059773
# Iteration number:
# 75
#  function value=
# 185.9773905947502
# 0.889486703772418
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 32.176943999490454
# Iteration number: 50 function value= 33.66422893271711
# Iteration number: 75 function value= 31.926292880977236
# Iteration number: 61
# Iteration number:
# 0
#  function value=
# 3.154604326625933e-26
# Iteration number:
# 25
#  function value=
# 73.21058547235644
# Iteration number:
# 50
#  function value=
# 182.42079909219382
# Iteration number:
# 75
#  function value=
# 186.1181094215989
# 0.9611131725417438
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 32.59316694164351
# Iteration number: 50 function value= 32.49839099568796
# Iteration number: 75 function value= 30.39907232638678
# Iteration number: 62
# Iteration number:
# 0
#  function value=
# 3.191538024799257e-26
# Iteration number:
# 25
#  function value=
# 75.9709927861661
# Iteration number:
# 50
#  function value=
# 175.30955570789214
# Iteration number:
# 75
#  function value=
# 180.1392205845765
# 0.8746815089672232
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 32.45282271219867
# Iteration number: 50 function value= 31.605548808856458
# Iteration number: 75 function value= 31.3499359030469
# Iteration number: 63
# Iteration number:
# 0
#  function value=
# 3.128458348209691e-26
# Iteration number:
# 25
#  function value=
# 65.65505899809249
# Iteration number:
# 50
#  function value=
# 171.3543918403488
# Iteration number:
# 75
#  function value=
# 175.12934764619823
# 0.9425479282622139
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 28.577964273096292
# Iteration number: 50 function value= 30.213839504709576
# Iteration number: 75 function value= 29.939659567905473
# Iteration number: 64
# Iteration number:
# 0
#  function value=
# 3.097593731229511e-26
# Iteration number:
# 25
#  function value=
# 61.69824831013656
# Iteration number:
# 50
#  function value=
# 171.09186287086723
# Iteration number:
# 75
#  function value=
# 174.83880690462786
# 0.9971923314780458
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 30.6505254686963
# Iteration number: 50 function value= 30.97653190052813
# Iteration number: 75 function value= 32.63694126420144
# Iteration number: 65
# Iteration number:
# 0
#  function value=
# 3.108898039539135e-26
# Iteration number:
# 25
#  function value=
# 59.723380602040365
# Iteration number:
# 50
#  function value=
# 169.0822493583637
# Iteration number:
# 75
#  function value=
# 173.2524855885706
# 0.8870995670995669
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 30.342223264862064
# Iteration number: 50 function value= 30.009077323047492
# Iteration number: 75 function value= 31.155593349311566
# Iteration number: 66
# Iteration number:
# 0
#  function value=
# 3.1120183616323324e-26
# Iteration number:
# 25
#  function value=
# 70.39413637146305
# Iteration number:
# 50
#  function value=
# 169.09899915741929
# Iteration number:
# 75
#  function value=
# 172.68802011177235
# 0.9990723562152134
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 31.47984612459323
# Iteration number: 50 function value= 32.075547541132835
# Iteration number: 75 function value= 28.66163904646035
# Iteration number: 67
# Iteration number:
# 0
#  function value=
# 3.1507841555484474e-26
# Iteration number:
# 25
#  function value=
# 68.94153129523
# Iteration number:
# 50
#  function value=
# 169.35669881604258
# Iteration number:
# 75
#  function value=
# 173.34901686849827
# 0.8846753246753246
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 32.768118353813186
# Iteration number: 50 function value= 29.561221983756113
# Iteration number: 75 function value= 32.33091475393653
# Iteration number: 68
# Iteration number:
# 0
#  function value=
# 3.209072626553618e-26
# Iteration number:
# 25
#  function value=
# 53.12304093346335
# Iteration number:
# 50
#  function value=
# 161.6227240214156
# Iteration number:
# 75
#  function value=
# 166.58675643641163
# 0.9015337043908472
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 27.81029914968534
# Iteration number: 50 function value= 29.762256983438263
# Iteration number: 75 function value= 30.61294491284526
# Iteration number: 69
# Iteration number:
# 0
#  function value=
# 3.109436456583014e-26
# Iteration number:
# 25
#  function value=
# 53.48214982058978
# Iteration number:
# 50
#  function value=
# 160.75320015296668
# Iteration number:
# 75
#  function value=
# 165.14929342754556
# 0.9972789115646258
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 27.538898045949146
# Iteration number: 50 function value= 29.448586785886377
# Iteration number: 75 function value= 27.964889814357548
# Iteration number: 70
# Iteration number:
# 0
#  function value=
# 3.1672146509761883e-26
# Iteration number:
# 25
#  function value=
# 67.90782342229313
# Iteration number:
# 50
#  function value=
# 156.4769595750891
# Iteration number:
# 75
#  function value=
# 161.53990562161812
# 0.9404823747680889
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 29.722319844819907
# Iteration number: 50 function value= 28.552464421680465
# Iteration number: 75 function value= 29.858598340801358
# Iteration number: 71
# Iteration number:
# 0
#  function value=
# 3.21462042722845e-26
# Iteration number:
# 25
#  function value=
# 34.332286890409975
# Iteration number:
# 50
#  function value=
# 154.2724145752373
# Iteration number:
# 75
#  function value=
# 158.10682212229642
# 0.8855658627087198
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 25.814898079912826
# Iteration number: 50 function value= 27.879855396649496
# Iteration number: 75 function value= 26.60285865437435
# Iteration number: 72
# Iteration number:
# 0
#  function value=
# 3.187294129124562e-26
# Iteration number:
# 25
#  function value=
# 14.095609812305895
# Iteration number:
# 50
#  function value=
# 149.52089297459037
# Iteration number:
# 75
#  function value=
# 153.22573081137375
# 0.844465058750773
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 23.63002106612936
# Iteration number: 50 function value= 25.910832430588975
# Iteration number: 75 function value= 29.49361090590306
# Iteration number: 73
# Iteration number:
# 0
#  function value=
# 3.1489754169568223e-26
# Iteration number:
# 25
#  function value=
# 20.807998056790286
# Iteration number:
# 50
#  function value=
# 149.14322165306822
# Iteration number:
# 75
#  function value=
# 152.7774691326909
# 0.9972047000618429
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 26.289962123518404
# Iteration number: 50 function value= 28.18682852703876
# Iteration number: 75 function value= 25.072150928959722
# Iteration number: 74
# Iteration number:
# 0
#  function value=
# 3.158589871475922e-26
# Iteration number:
# 25
#  function value=
# 19.48244871831887
# Iteration number:
# 50
#  function value=
# 147.12274565743633
# Iteration number:
# 75
#  function value=
# 151.16105415912642
# 0.8817316017316017
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 24.66276699485303
# Iteration number: 50 function value= 26.496779954869815
# Iteration number: 75 function value= 27.839139453426498
# Iteration number: 75
# Iteration number:
# 0
#  function value=
# 3.2043214243954125e-26
# Iteration number:
# 25
#  function value=
# 9.281101157657885
# Iteration number:
# 50
#  function value=
# 149.72089749562102
# Iteration number:
# 75
#  function value=
# 153.89555408803756
# 0.9983178726035868
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 28.263148843338186
# Iteration number: 50 function value= 27.13853823624404
# Iteration number: 75 function value= 28.18738774279651
# Iteration number: 76
# Iteration number:
# 0
#  function value=
# 3.24668805804792e-26
# Iteration number:
# 25
#  function value=
# 39.01315867219046
# Iteration number:
# 50
#  function value=
# 146.9553177277166
# Iteration number:
# 75
#  function value=
# 150.85102991559742
# 0.9418305504019788
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 21.976860919666102
# Iteration number: 50 function value= 27.957835563561098
# Iteration number: 75 function value= 26.397581233353957
# Iteration number: 77
# Iteration number:
# 0
#  function value=
# 3.202181155716471e-26
# Iteration number:
# 25
#  function value=
# 4.927021382739837
# Iteration number:
# 50
#  function value=
# 141.07884438924884
# Iteration number:
# 75
#  function value=
# 145.36122434744652
# 0.8769820655534941
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 25.993936402407634
# Iteration number: 50 function value= 25.668329997808204
# Iteration number: 75 function value= 24.37390037154777
# Iteration number: 78
# Iteration number:
# 0
#  function value=
# 3.216622793557858e-26
# Iteration number:
# 25
#  function value=
# 1.4950759530411917
# Iteration number:
# 50
#  function value=
# 132.95238332017237
# Iteration number:
# 75
#  function value=
# 139.77918062209258
# 0.9347433518862089
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 23.054112450477778
# Iteration number: 50 function value= 25.994269790816386
# Iteration number: 75 function value= 23.538513636514132
# Iteration number: 79
# Iteration number:
# 0
#  function value=
# 3.13408549420649e-26
# Iteration number:
# 25
#  function value=
# 27.299754077687126
# Iteration number:
# 50
#  function value=
# 134.54970365737347
# Iteration number:
# 75
#  function value=
# 138.89414703470442
# 0.9412121212121211
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 23.887133730865393
# Iteration number: 50 function value= 24.775614247948955
# Iteration number: 75 function value= 24.268717929171086
# Iteration number: 80
# Iteration number:
# 0
#  function value=
# 3.1275576277808444e-26
# Iteration number:
# 25
#  function value=
# 9.91301489502467
# Iteration number:
# 50
#  function value=
# 136.6805631698682
# Iteration number:
# 75
#  function value=
# 140.6452845950306
# 0.9395176252319108
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 24.215407803748477
# Iteration number: 50 function value= 24.501027208505068
# Iteration number: 75 function value= 25.322611947402912
# Iteration number: 81
# Iteration number:
# 0
#  function value=
# 3.0376381022045383e-26
# Iteration number:
# 25
#  function value=
# 2.582968502340831
# Iteration number:
# 50
#  function value=
# 125.93635882648704
# Iteration number:
# 75
#  function value=
# 137.75535686204842
# 0.8840197897340754
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 22.393352175125816
# Iteration number: 50 function value= 26.74582331039455
# Iteration number: 75 function value= 24.287307046288824
# Iteration number: 82
# Iteration number:
# 0
#  function value=
# 3.079651468347542e-26
# Iteration number:
# 25
#  function value=
# 3.759916930935819
# Iteration number:
# 50
#  function value=
# 130.0883570676301
# Iteration number:
# 75
#  function value=
# 134.88826387225822
# 0.9972665429808286
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 24.56659415964903
# Iteration number: 50 function value= 24.458365916630534
# Iteration number: 75 function value= 24.428325185631948
# Iteration number: 83
# Iteration number:
# 0
#  function value=
# 3.120662074427498e-26
# Iteration number:
# 25
#  function value=
# 0.09770785295312033
# Iteration number:
# 50
#  function value=
# 130.66025519969958
# Iteration number:
# 75
#  function value=
# 135.25716946111135
# 0.9976004947433518
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 23.27107920464365
# Iteration number: 50 function value= 25.12108739917323
# Iteration number: 75 function value= 23.579415017358595
# Iteration number: 84
# Iteration number:
# 0
#  function value=
# 3.1418347979896835e-26
# Iteration number:
# 25
#  function value=
# 0.145629021701704
# Iteration number:
# 50
#  function value=
# 126.23509290431596
# Iteration number:
# 75
#  function value=
# 130.14881703028098
# 0.8888806431663574
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 22.619473853213172
# Iteration number: 50 function value= 21.25859339554816
# Iteration number: 75 function value= 24.572289265805633
# Iteration number: 85
# Iteration number:
# 0
#  function value=
# 3.103690374836334e-26
# Iteration number:
# 25
#  function value=
# 0.37060507168839635
# Iteration number:
# 50
#  function value=
# 130.07401331697108
# Iteration number:
# 75
#  function value=
# 134.36112608211187
# 0.9350030921459492
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 23.309234325038837
# Iteration number: 50 function value= 23.159090050122597
# Iteration number: 75 function value= 24.36165434324291
# Iteration number: 86
# Iteration number:
# 0
#  function value=
# 3.2423897896354055e-26
# Iteration number:
# 25
#  function value=
# 0.4114593923224461
# Iteration number:
# 50
#  function value=
# 128.23969031368787
# Iteration number:
# 75
#  function value=
# 132.23583057749585
# 0.9973531230674086
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 24.752726099258293
# Iteration number: 50 function value= 25.195995057313866
# Iteration number: 75 function value= 20.81954583536985
# Iteration number: 87
# Iteration number:
# 0
#  function value=
# 3.118301892340173e-26
# Iteration number:
# 25
#  function value=
# 0.3965371279307118
# Iteration number:
# 50
#  function value=
# 125.76209722885244
# Iteration number:
# 75
#  function value=
# 132.31936886375746
# 0.9334817563388992
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 23.955183558922357
# Iteration number: 50 function value= 25.052011476102614
# Iteration number: 75 function value= 23.889152906516728
# Iteration number: 88
# Iteration number:
# 0
#  function value=
# 3.1487791478051484e-26
# Iteration number:
# 25
#  function value=
# 0.9355684672996476
# Iteration number:
# 50
#  function value=
# 117.8766279315713
# Iteration number:
# 75
#  function value=
# 125.54377761626378
# 0.8807915893630179
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 21.628683760655573
# Iteration number: 50 function value= 21.66276038900187
# Iteration number: 75 function value= 23.96985531169571
# Iteration number: 89
# Iteration number:
# 0
#  function value=
# 3.044021952526253e-26
# Iteration number:
# 25
#  function value=
# 0.19326888875817172
# Iteration number:
# 50
#  function value=
# 119.33045854372136
# Iteration number:
# 75
#  function value=
# 125.33737341710773
# 0.9395299938157081
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 21.269393948969295
# Iteration number: 50 function value= 21.60748939608114
# Iteration number: 75 function value= 23.612017663375752
# Iteration number: 90
# Iteration number:
# 0
#  function value=
# 3.1232267357489255e-26
# Iteration number:
# 25
#  function value=
# 0.6927459667973223
# Iteration number:
# 50
#  function value=
# 118.33547667584529
# Iteration number:
# 75
#  function value=
# 126.91386007240973
# 0.8856029684601112
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 23.142925305690397
# Iteration number: 50 function value= 21.298774310479644
# Iteration number: 75 function value= 23.630525041056508
# Iteration number: 91
# Iteration number:
# 0
#  function value=
# 3.156187727721628e-26
# Iteration number:
# 25
#  function value=
# 0.006669884211699692
# Iteration number:
# 50
#  function value=
# 116.9344398928573
# Iteration number:
# 75
#  function value=
# 122.42053766806953
# 0.883834260977118
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 19.525233720709583
# Iteration number: 50 function value= 23.415961205271856
# Iteration number: 75 function value= 22.496102112775556
# Iteration number: 92
# Iteration number:
# 0
#  function value=
# 3.0682601837688293e-26
# Iteration number:
# 25
#  function value=
# 0.017831538062121767
# Iteration number:
# 50
#  function value=
# 113.24185208890641
# Iteration number:
# 75
#  function value=
# 121.10726835304814
# 0.9404823747680889
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 18.505604788088768
# Iteration number: 50 function value= 19.71270580385996
# Iteration number: 75 function value= 21.789744778271782
# Iteration number: 93
# Iteration number:
# 0
#  function value=
# 3.1800737105413184e-26
# Iteration number:
# 25
#  function value=
# 0.04050980403671236
# Iteration number:
# 50
#  function value=
# 118.56160492673085
# Iteration number:
# 75
#  function value=
# 123.33994426142128
# 0.9397526283240568
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 20.415335645452096
# Iteration number: 50 function value= 20.62826539779469
# Iteration number: 75 function value= 22.706042160539994
# Iteration number: 94
# Iteration number:
# 0
#  function value=
# 3.084353786644461e-26
# Iteration number:
# 25
#  function value=
# 0.08703735449205849
# Iteration number:
# 50
#  function value=
# 115.48670079067819
# Iteration number:
# 75
#  function value=
# 119.17095361180836
# 0.9971057513914656
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 20.357081399508512
# Iteration number: 50 function value= 21.28749765669536
# Iteration number: 75 function value= 21.100233012519215
# Iteration number: 95
# Iteration number:
# 0
#  function value=
# 3.0821942296297204e-26
# Iteration number:
# 25
#  function value=
# 0.004972715502586966
# Iteration number:
# 50
#  function value=
# 110.42218799922739
# Iteration number:
# 75
#  function value=
# 116.23461681844654
# 0.9378602350030921
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 19.362649355714993
# Iteration number: 50 function value= 19.725335347588363
# Iteration number: 75 function value= 23.812132515386672
# Iteration number: 96
# Iteration number:
# 0
#  function value=
# 3.087362943747904e-26
# Iteration number:
# 25
#  function value=
# 0.009974657171014813
# Iteration number:
# 50
#  function value=
# 111.52055195612263
# Iteration number:
# 75
#  function value=
# 116.04951392987542
# 0.9959307359307359
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 19.497357586528647
# Iteration number: 50 function value= 20.918786693762392
# Iteration number: 75 function value= 20.163554188062065
# Iteration number: 97
# Iteration number:
# 0
#  function value=
# 2.9184760589395586e-26
# Iteration number:
# 25
#  function value=
# 0.001873266009154157
# Iteration number:
# 50
#  function value=
# 105.09812749908035
# Iteration number:
# 75
#  function value=
# 113.18272975971516
# 0.9891774891774892
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 17.814094072793267
# Iteration number: 50 function value= 22.57920337981856
# Iteration number: 75 function value= 19.433857737045493
# Iteration number: 98
# Iteration number:
# 0
#  function value=
# 3.105625771370001e-26
# Iteration number:
# 25
#  function value=
# 0.0010758320856636137
# Iteration number:
# 50
#  function value=
# 108.19993541326265
# Iteration number:
# 75
#  function value=
# 112.05594934373839
# 0.8974025974025973
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 17.62962204842473
# Iteration number: 50 function value= 18.212139513151513
# Iteration number: 75 function value= 20.73802543252649
# Iteration number: 99
# Iteration number:
# 0
#  function value=
# 3.113434862824266e-26
# Iteration number:
# 25
#  function value=
# 0.0001978729733727468
# Iteration number:
# 50
#  function value=
# 101.60517588157941
# Iteration number:
# 75
#  function value=
# 106.49057534087333
# 0.8366604823747681
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 17.103767329336094
# ...
# Iteration number: 967
# Iteration number:
# 0
#  function value=
# 2.89116328934542e-26
# Iteration number:
# 25
#  function value=
# 1.231969194727669e-12
# Iteration number:
# 50
#  function value=
# 15.988056483607972
# Iteration number:
# 75
#  function value=
# 48.62511587894228
# 0.31191094619666043
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 6.8649841635765405
# Iteration number: 50 function value= 7.194975448199344
# Iteration number: 75 function value= 7.426735461693389
# Iteration number: 968
# Iteration number:
# 0
#  function value=
# 2.858241838378368e-26
# Iteration number:
# 25
#  function value=
# 2.0615485672358426e-13
# Iteration number:
# 50
#  function value=
# 15.765126277298467
# Iteration number:
# 75
#  function value=
# 48.2732498102381
# 0.1258256029684601
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 5.314576720056108
# Iteration number: 50 function value= 6.852642855290621
# Iteration number: 75 function value= 8.173638759366455
# Iteration number: 969
# Iteration number:
# 0
#  function value=
# 2.929264311109651e-26
# Iteration number:
# 25
#  function value=
# 4.887724711631476e-13
# Iteration number:
# 50
#  function value=
# 16.042605933792977
# Iteration number:
# 75
#  function value=
# 47.491491140437184
# 0.20283240568954855
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 6.269886551408106
# Iteration number: 50 function value= 7.054187923952991
# Iteration number: 75 function value= 8.531239561930894
# Iteration number: 970
# Iteration number:
# 0
#  function value=
# 2.9449110152302564e-26
# Iteration number:
# 25
#  function value=
# 1.2826910786980382e-12
# Iteration number:
# 50
#  function value=
# 17.54054543793743
# Iteration number:
# 75
#  function value=
# 47.60342699125001
# 0.316573902288188
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 6.0249092862137
# Iteration number: 50 function value= 7.17536224372131
# Iteration number: 75 function value= 6.041164360614106
# Iteration number: 971
# Iteration number:
# 0
#  function value=
# 2.94169328784453e-26
# Iteration number:
# 25
#  function value=
# 5.748149899280814e-13
# Iteration number:
# 50
#  function value=
# 13.076005237518341
# Iteration number:
# 75
#  function value=
# 47.46288492129209
# 0.21047619047619046
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 6.586564180221618
# Iteration number: 50 function value= 8.163770437288823
# Iteration number: 75 function value= 8.04221703596122
# Iteration number: 972
# Iteration number:
# 0
#  function value=
# 3.008338477773043e-26
# Iteration number:
# 25
#  function value=
# 7.751240448823501e-12
# Iteration number:
# 50
#  function value=
# 18.403741836797263
# Iteration number:
# 75
#  function value=
# 46.79319161655451
# 0.40841063698206553
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 6.0832778298028565
# Iteration number: 50 function value= 7.189016032612626
# Iteration number: 75 function value= 7.547592237477225
# Iteration number: 973
# Iteration number:
# 0
#  function value=
# 2.8421567633166357e-26
# Iteration number:
# 25
#  function value=
# 5.150450031403612e-13
# Iteration number:
# 50
#  function value=
# 17.59231412957724
# Iteration number:
# 75
#  function value=
# 49.29497816968684
# 0.20869511440940014
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 6.716947578918664
# Iteration number: 50 function value= 7.287995329407844
# Iteration number: 75 function value= 7.819041117529296
# Iteration number: 974
# Iteration number:
# 0
#  function value=
# 2.8511392237804606e-26
# Iteration number:
# 25
#  function value=
# 3.3900472572418175e-13
# Iteration number:
# 50
#  function value=
# 16.829118588628006
# Iteration number:
# 75
#  function value=
# 47.677191512604544
# 0.13854050711193566
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 5.795748805635851
# Iteration number: 50 function value= 6.905697065086725
# Iteration number: 75 function value= 8.36817893687861
# Iteration number: 975
# Iteration number:
# 0
#  function value=
# 2.952978795383725e-26
# Iteration number:
# 25
#  function value=
# 1.1778043907005831e-11
# Iteration number:
# 50
#  function value=
# 17.535451655405563
# Iteration number:
# 75
#  function value=
# 46.6834301811168
# 0.20136054421768707
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 6.792030755082429
# Iteration number: 50 function value= 7.634558426255962
# Iteration number: 75 function value= 7.680708833501
# Iteration number: 976
# Iteration number:
# 0
#  function value=
# 2.8604975132263145e-26
# Iteration number:
# 25
#  function value=
# 3.5274250982553154e-12
# Iteration number:
# 50
#  function value=
# 18.069953164681504
# Iteration number:
# 75
#  function value=
# 45.76318596554745
# 0.21520098948670377
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 5.806381125418943
# Iteration number: 50 function value= 7.557793668785765
# Iteration number: 75 function value= 7.152630844454238
# Iteration number: 977
# Iteration number:
# 0
#  function value=
# 2.995896624988266e-26
# Iteration number:
# 25
#  function value=
# 1.6628873692970662e-12
# Iteration number:
# 50
#  function value=
# 18.43303845193872
# Iteration number:
# 75
#  function value=
# 46.6340566070504
# 0.17857761286332713
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 6.263502496600822
# Iteration number: 50 function value= 7.7358215201905995
# Iteration number: 75 function value= 7.5750391835466555
# Iteration number: 978
# Iteration number:
# 0
#  function value=
# 2.8334905501898566e-26
# Iteration number:
# 25
#  function value=
# 1.5468406716610211e-12
# Iteration number:
# 50
#  function value=
# 18.642262290534262
# Iteration number:
# 75
#  function value=
# 47.303704315220465
# 0.2928138528138528
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 6.091834042758273
# Iteration number: 50 function value= 7.8189100715437725
# Iteration number: 75 function value= 7.9439039752934315
# Iteration number: 979
# Iteration number:
# 0
#  function value=
# 2.9620712893934957e-26
# Iteration number:
# 25
#  function value=
# 2.114425196789064e-12
# Iteration number:
# 50
#  function value=
# 16.606054706615662
# Iteration number:
# 75
#  function value=
# 45.07879211740101
# 0.18270871985157697
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 5.630205403711852
# Iteration number: 50 function value= 7.385787006619309
# Iteration number: 75 function value= 8.37411048236215
# Iteration number: 980
# Iteration number:
# 0
#  function value=
# 2.918555629269141e-26
# Iteration number:
# 25
#  function value=
# 2.6290289903131318e-12
# Iteration number:
# 50
#  function value=
# 18.07052691000372
# Iteration number:
# 75
#  function value=
# 46.26205624508202
# 0.1766233766233766
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 5.89388844598953
# Iteration number: 50 function value= 7.060221600195678
# Iteration number: 75 function value= 7.422264629235916
# Iteration number: 981
# Iteration number:
# 0
#  function value=
# 2.9630408479153036e-26
# Iteration number:
# 25
#  function value=
# 1.5847860921260311e-12
# Iteration number:
# 50
#  function value=
# 18.82215477237825
# Iteration number:
# 75
#  function value=
# 50.92644551241814
# 0.400717377860235
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 6.103508694501124
# Iteration number: 50 function value= 7.541652515578793
# Iteration number: 75 function value= 7.1791477531858785
# Iteration number: 982
# Iteration number:
# 0
#  function value=
# 2.936736996685067e-26
# Iteration number:
# 25
#  function value=
# 1.2217257333074488e-12
# Iteration number:
# 50
#  function value=
# 18.27873406341113
# Iteration number:
# 75
#  function value=
# 50.02633953998682
# 0.1566852195423624
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 7.045258505735713
# Iteration number: 50 function value= 7.299706338998466
# Iteration number: 75 function value= 8.33519351747712
# Iteration number: 983
# Iteration number:
# 0
#  function value=
# 2.859247192865003e-26
# Iteration number:
# 25
#  function value=
# 4.8161835432122155e-12
# Iteration number:
# 50
#  function value=
# 21.047875273365104
# Iteration number:
# 75
#  function value=
# 48.697816603074905
# 0.22299319727891154
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 7.842551221329114
# Iteration number: 50 function value= 8.190713767100009
# Iteration number: 75 function value= 9.593586252925862
# Iteration number: 984
# Iteration number:
# 0
#  function value=
# 2.9440956831780177e-26
# Iteration number:
# 25
#  function value=
# 1.149913508669957e-12
# Iteration number:
# 50
#  function value=
# 17.34158577047832
# Iteration number:
# 75
#  function value=
# 47.71966811687892
# 0.17640074211502782
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 6.869125902950643
# Iteration number: 50 function value= 6.710467335466495
# Iteration number: 75 function value= 7.514500654550202
# Iteration number: 985
# Iteration number:
# 0
#  function value=
# 2.937269130337793e-26
# Iteration number:
# 25
#  function value=
# 1.1062954479575705e-12
# Iteration number:
# 50
#  function value=
# 15.580258026666215
# Iteration number:
# 75
#  function value=
# 43.1702146695429
# 0.20624613481756338
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 5.63763327858266
# Iteration number: 50 function value= 7.843023945218414
# Iteration number: 75 function value= 7.845515552419229
# Iteration number: 986
# Iteration number:
# 0
#  function value=
# 2.8875775553629465e-26
# Iteration number:
# 25
#  function value=
# 3.199445357820419e-12
# Iteration number:
# 50
#  function value=
# 18.384144178526586
# Iteration number:
# 75
#  function value=
# 48.3194725952515
# 0.17520098948670376
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 5.89299780832798
# Iteration number: 50 function value= 7.976458790971936
# Iteration number: 75 function value= 7.862186150889798
# Iteration number: 987
# Iteration number:
# 0
#  function value=
# 3.0137936849587983e-26
# Iteration number:
# 25
#  function value=
# 6.757812972174471e-13
# Iteration number:
# 50
#  function value=
# 17.051664209670257
# Iteration number:
# 75
#  function value=
# 46.852369880167444
# 0.22393320964749533
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 7.137223757421916
# Iteration number: 50 function value= 8.18571713212434
# Iteration number: 75 function value= 8.735497489600295
# Iteration number: 988
# Iteration number:
# 0
#  function value=
# 2.936359087253051e-26
# Iteration number:
# 25
#  function value=
# 4.183855283396756e-12
# Iteration number:
# 50
#  function value=
# 19.48045423498079
# Iteration number:
# 75
#  function value=
# 48.980817330025616
# 0.23408781694495978
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 5.888274654393976
# Iteration number: 50 function value= 7.170553713450975
# Iteration number: 75 function value= 8.453760269747473
# Iteration number: 989
# Iteration number:
# 0
#  function value=
# 2.9198829895477556e-26
# Iteration number:
# 25
#  function value=
# 2.522275501995314e-12
# Iteration number:
# 50
#  function value=
# 18.615009876120286
# Iteration number:
# 75
#  function value=
# 50.6157573946267
# 0.16774273345701915
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 6.806423390837155
# Iteration number: 50 function value= 6.9002986465294684
# Iteration number: 75 function value= 7.659978113368878
# Iteration number: 990
# Iteration number:
# 0
#  function value=
# 2.956341715005336e-26
# Iteration number:
# 25
#  function value=
# 6.940560337295617e-12
# Iteration number:
# 50
#  function value=
# 19.544912822203692
# Iteration number:
# 75
#  function value=
# 48.53332384579977
# 0.2163883735312307
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 5.6493027572957555
# Iteration number: 50 function value= 7.461217290023783
# Iteration number: 75 function value= 7.715083990827849
# Iteration number: 991
# Iteration number:
# 0
#  function value=
# 2.8339030375372556e-26
# Iteration number:
# 25
#  function value=
# 1.0557177049874414e-12
# Iteration number:
# 50
#  function value=
# 18.512876393482937
# Iteration number:
# 75
#  function value=
# 50.26348890446956
# 0.2863945578231292
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 6.519823595331529
# Iteration number: 50 function value= 8.098281565999606
# Iteration number: 75 function value= 8.393383003272106
# Iteration number: 992
# Iteration number:
# 0
#  function value=
# 2.9306048801513836e-26
# Iteration number:
# 25
#  function value=
# 9.99834148635e-13
# Iteration number:
# 50
#  function value=
# 17.80666188508165
# Iteration number:
# 75
#  function value=
# 49.1485326249434
# 0.19842918985776126
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 5.730868888650047
# Iteration number: 50 function value= 8.093535587849475
# Iteration number: 75 function value= 8.128509210280157
# Iteration number: 993
# Iteration number:
# 0
#  function value=
# 2.992627696059294e-26
# Iteration number:
# 25
#  function value=
# 4.696140816216825e-13
# Iteration number:
# 50
#  function value=
# 16.138309480922054
# Iteration number:
# 75
#  function value=
# 48.38234483734506
# 0.2898206555349412
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 6.972509105039
# Iteration number: 50 function value= 6.365251142767081
# Iteration number: 75 function value= 7.406711303854552
# Iteration number: 994
# Iteration number:
# 0
#  function value=
# 2.9113555546449847e-26
# Iteration number:
# 25
#  function value=
# 3.418635144762953e-13
# Iteration number:
# 50
#  function value=
# 18.26853377380236
# Iteration number:
# 75
#  function value=
# 47.46987712430547
# 0.15265306122448977
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 5.319378592120291
# Iteration number: 50 function value= 6.775749775641451
# Iteration number: 75 function value= 8.506576043816853
# Iteration number: 995
# Iteration number:
# 0
#  function value=
# 2.898982828744005e-26
# Iteration number:
# 25
#  function value=
# 3.1685755455184946e-12
# Iteration number:
# 50
#  function value=
# 18.277514297951125
# Iteration number:
# 75
#  function value=
# 48.33041467341536
# 0.3063203463203463
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 6.815002834677103
# Iteration number: 50 function value= 6.815997671374907
# Iteration number: 75 function value= 9.08926938018127
# Iteration number: 996
# Iteration number:
# 0
#  function value=
# 2.965181118728207e-26
# Iteration number:
# 25
#  function value=
# 1.0166852282939409e-12
# Iteration number:
# 50
#  function value=
# 17.2591982842439
# Iteration number:
# 75
#  function value=
# 49.40814907242128
# 0.16207792207792204
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 6.341354586257225
# Iteration number: 50 function value= 7.211681755728816
# Iteration number: 75 function value= 7.323810887246916
# Iteration number: 997
# Iteration number:
# 0
#  function value=
# 2.884574889129037e-26
# Iteration number:
# 25
#  function value=
# 2.008480687337604e-12
# Iteration number:
# 50
#  function value=
# 20.248665286733505
# Iteration number:
# 75
#  function value=
# 48.48115096224871
# 0.23700680272108843
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 6.985261074768454
# Iteration number: 50 function value= 6.556358826249603
# Iteration number: 75 function value= 7.882015680779858
# Iteration number: 998
# Iteration number:
# 0
#  function value=
# 2.94544916407129e-26
# Iteration number:
# 25
#  function value=
# 3.5526396998340985e-12
# Iteration number:
# 50
#  function value=
# 19.321673212705154
# Iteration number:
# 75
#  function value=
# 49.033100092130795
# 0.21688311688311687
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 6.099964993697095
# Iteration number: 50 function value= 6.682723310554358
# Iteration number: 75 function value= 7.433514331325052
# Iteration number: 999
# Iteration number:
# 0
#  function value=
# 2.9049239649883875e-26
# Iteration number:
# 25
#  function value=
# 2.9140148579800836e-12
# Iteration number:
# 50
#  function value=
# 19.536853484646855
# Iteration number:
# 75
#  function value=
# 49.09964890261222
# 0.1403834260977118
# Iteration number: 0 function value= 0
# Iteration number: 25 function value= 5.779611087407712
# Iteration number: 50 function value= 7.743732194939004
# Iteration number: 75 function value= 7.549393491898627

# %%
fig, ax = plt.subplots()

ax.plot((np.array(snr_list)),(np.array(corr_list)), 'bo',color='b' , label="No use of prior knowledge")
ax.plot( (np.array(snr_list)),savgol_filter(np.array((np.array(corr_list))),97,3), 'k', linewidth=3.0 )#, label="No use of prior knowledge smoothed")
ax.plot((np.array(snr_list)),(np.array(corr_list_in)), 'bo',color='g' , label="Use prior knowledge of 3 bins")
ax.plot( (np.array(snr_list)),savgol_filter(np.array((np.array(corr_list_in))),97,3), 'k', linewidth=3.0)# , label="Use prior knowledge smoothed")
plt.legend()
ax.set_xlabel("SNR ",  fontsize=16)
ax.set_ylabel("Spearman correlation ",  fontsize=16)
ax.set_title("Spearman correlation as function of the SNR ",  fontsize=16)
ax.grid(True)
ax.invert_xaxis()
plt.tick_params(labelsize=16)
plt.ylim(0, 1.1)

plt.show()

plt.show()
# Out:
# /var/folders/yk/yt973zks3y50tkwcqhndwqrm0000gn/T/ipykernel_45676/4154436406.py:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bo" (-> color='b'). The keyword argument will take precedence.
#   ax.plot((np.array(snr_list)),(np.array(corr_list)), 'bo',color='b' , label="No use of prior knowledge")
# /var/folders/yk/yt973zks3y50tkwcqhndwqrm0000gn/T/ipykernel_45676/4154436406.py:5: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bo" (-> color='b'). The keyword argument will take precedence.
#   ax.plot((np.array(snr_list)),(np.array(corr_list_in)), 'bo',color='g' , label="Use prior knowledge of 3 bins")
